# %%
import pandas as pd
from tqdm import tqdm
import numpy as np
import cv2
import os
from datetime import timedelta
import sys
from pathlib import Path

# %%
info = {}
with open('train/разметка.txt', 'r') as f:
    for line in f:
        if 'mp4' in line:
            file_name = line.strip()
            info[file_name] = []
        else:
            if line.strip() != '':
                info[file_name].append(line.strip())

# %%
info
# Out:
# {'0000000_00000020240221082923_0001_IMP (1).mp4': ['01:43',
#   '06:10',
#   '10:49',
#   '10:56'],
#  '0000000_00000020240221084423_0002_IMP.mp4': ['07:05', '08:10'],
#  '0000000_00000020240221085923_0003_IMP.mp4': ['09:15', '13:38', '13:48'],
#  '0000000_00000020240508114229_0002.mp4': ['02:28', '05:33', '07:04'],
#  '0000000_00000020240508132920_0006.mp4': ['00:47', '01:53'],
#  '2_5395803543229709215.mp4': ['00:01',
#   '02:01',
#   '02:18',
#   '02:47',
#   '03:12',
#   '11:47',
#   '12:43'],
#  '2_5395803543229709261.mp4': ['01:43'],
#  '2_5395803543229709728.mp4': ['01:20'],
#  '2_5395803543229709828.mp4': ['04:39', '05:10'],
#  '27e2fbc6-8579-4f48-852d-a42fd49522a2.mp4': ['-'],
#  'VID_20240304_095112.mp4': ['00:21'],
#  'VID_20240304_095227.mp4': ['-'],
#  'VID_20240304_095302.mp4': ['-'],
#  'VID_20240304_095352.mp4': ['00:07'],
#  'VID_20240304_095423.mp4': ['00:03'],
#  'VID_20240305_130307.mp4': ['-'],
#  'VID_20240305_130357.mp4': ['-'],
#  'VID_20240305_130642.mp4': ['-'],
#  'VID_20240305_130713.mp4': ['-'],
#  'VID_20240311_115448.mp4': ['-'],
#  'VID_20240311_115528.mp4': ['-'],
#  'VID_20240311_115938.mp4': ['-'],
#  'VID_20240311_154731.mp4': ['00:00', '00:04'],
#  'VID_20240311_154807.mp4': ['-'],
#  'VID_20240311_154843.mp4': ['-'],
#  'VID_20240311_154921.mp4': ['00:05'],
#  'VID_20240311_155103.mp4': ['-'],
#  'VID_20240313_155024.mp4': ['-'],
#  'VID_20240313_155059.mp4': ['-'],
#  'VID_20240313_155129.mp4': ['-'],
#  'VID_20240313_155201.mp4': ['-'],
#  'VID_20240313_155312.mp4': ['-'],
#  'VID_20240313_155411.mp4': ['-'],
#  'VID_20240313_155451.mp4': ['-'],
#  'VID_20240313_155808.mp4': ['-'],
#  'VID-20240227-WA0030.mp4': ['-'],
#  'VID-20240301-WA0022.mp4': ['00:21', '00:55'],
#  'VID-20240301-WA0023.mp4': ['02:16']}

# %%
files_wo_markup = []
for key, val in info.items():
    if val[0] == '-':
        files_wo_markup.append(key)

# %%
len(files_wo_markup)
# Out:
# 22

# %%
len(info.keys())
# Out:
# 38

# %%
def format_timedelta(td):
    """Служебная функция для классного форматирования объектов timedelta (например, 00:00:20.05)
    исключая микросекунды и сохраняя миллисекунды"""
    result = str(td)
    try:
        result, ms = result.split(".")
    except ValueError:
        return (result + ".00").replace(":", "-")
    ms = int(ms)
    ms = round(ms / 1e4)
    return f"{result}.{ms:02}".replace(":", "-")

# %%
def get_saving_frames_durations(cap, saving_fps, df, delta = 5):
    """Функция, которая возвращает список длительностей, в которые следует сохранять кадры.
    df - инфо по нарушениям 
    delta - сколько секунд отступаем до нарушения
    """

    # получаем продолжительность клипа, разделив количество кадров на количество кадров в секунду
    clip_duration = cap.get(cv2.CAP_PROP_FRAME_COUNT) / cap.get(cv2.CAP_PROP_FPS)
        
    flags = [] # метки флага нарушений
    number_of_violent = [] # номер нарушения в кадре
    descr_list = [] # список описаний кадров
    s = [] 
    end_old = -1
    for idx, row in df.iterrows():

        m_start = row.start.minute
        s_start = row.start.second

        m_end = row.end.minute
        s_end = row.end.second

         # преобразуем время нарушений в секунды    
        start = m_start*60 + s_start
        end = m_end*60 + s_end
        
        # определяем время начала нарушения
        if start-delta < end_old:
            start_new = start
        else: 
            start_new = start-delta
            
        descr = row.description
        
        # определяем список кадров    
        for i in np.arange(start_new, end, 1 / saving_fps):
            s.append(i)
            number_of_violent.append(idx)
            if i < start:
                #  до начала нарушения флаг 0           
                flags.append(0)
                descr_list.append(None)
            else:
                flags.append(1)
                descr_list.append(descr)
        end_old = end
    return (s, number_of_violent, flags, descr_list)

# %%
def main(video_file, video_name, video_num, df, delta, save_dir, make_dir=False):
    """
    Функция выделяет в видео отрезки с нарушенями и за __ секунд до нарушения,
    создает кадры и сохраняет их в заданную папку.
    
    Args:
        video_file - путь до видео
        video_name - название видео
        video_num - номер видео
        df - данные по нарушениям для конкретного видео
        delta - сколько секунд отступаем до нарушения
        make_dir - сохраняем в одну папку или в разные
        save_dir - куда сохраняем
    """
    file_names = pd.DataFrame()
    
    # создаем папку для сохранения результатов
    if not os.path.isdir(save_dir):
        os.mkdir(save_dir)
        
    filename = save_dir
    
    if make_dir:
        filename, _ = os.path.splitext(video_name)
        filename = os.path.join(save_dir, filename+"_opencv")    
        # создаем индивидуальную папку для сохранения результатов
        if not os.path.isdir(filename):
            os.mkdir(filename)
            
    # читать видео файл    
    cap = cv2.VideoCapture(video_file)
    # получить FPS видео
    fps = cap.get(cv2.CAP_PROP_FPS)
    # если SAVING_FRAMES_PER_SECOND выше видео FPS, то установите его на FPS (как максимум)
    saving_frames_per_second = min(fps, SAVING_FRAMES_PER_SECOND)
    # получить список длительностей для сохранения
    saving_frames_durations, number_of_violent, flags, descr_list = get_saving_frames_durations(cap, saving_frames_per_second, df, delta)
    # запускаем цикл
    count = 0
    save_frame_count = 0
    while True:
        is_read, frame = cap.read()
        if not is_read:
            # выйти из цикла, если нет фреймов для чтения
            break
        # получаем продолжительность, разделив количество кадров на FPS
        frame_duration = count / fps
        try:
            # получить самую раннюю продолжительность для сохранения
            closest_duration = saving_frames_durations[0]
        except IndexError:
            # список пуст, все кадры длительности сохранены
            break
        if frame_duration >= closest_duration:

            # если ближайшая длительность меньше или равна длительности кадра,
            # затем сохраняем фрейм
            frame_duration_formatted = format_timedelta(timedelta(seconds=frame_duration))           
            
            count_violation = number_of_violent[save_frame_count]
            flag = flags[save_frame_count]
            descr = descr_list[save_frame_count]
            frame_name = f"video_{video_num}_frame_{frame_duration_formatted}_flag_{flag}_violation_{count_violation}.jpg"
#             print(frame_name)

            cv2.imwrite(os.path.join(filename, frame_name), frame) 
            file_df = pd.DataFrame({'video_name': video_name,
                                 'video_num': video_num,
                                 'image_name': frame_name,
                                 'frame_duration': frame_duration_formatted,
                                 'target': flag,
                                 'description': descr}, index=[0])
            file_names = pd.concat([file_names, file_df], ignore_index=True)
    
#             file_names.append(frame_name)
            save_frame_count += 1
            # удалить точку продолжительности из списка, так как эта точка длительности уже сохранена
            try:
                saving_frames_durations.pop(0)
            except IndexError:
                pass
        # увеличить количество кадров
        count += 1
    return file_names

# %%
info_df = pd.read_excel('разметка.xlsx')

# %%
info_df
# Out:
#                                         videofile     start       end  \
# 0   0000000_00000020240221082923_0001_IMP (1).mp4  00:01:00  00:01:00
# 1   0000000_00000020240221082923_0001_IMP (1).mp4  00:06:00  06:22:00
# 2   0000000_00000020240221082923_0001_IMP (1).mp4  00:10:00  00:10:00
# 3   0000000_00000020240221082923_0001_IMP (1).mp4  00:10:00  00:11:00
# 4       0000000_00000020240221084423_0002_IMP.mp4  00:07:00  00:07:00
# 5       0000000_00000020240221084423_0002_IMP.mp4  00:08:00  00:08:00
# 6       0000000_00000020240221085923_0003_IMP.mp4  00:09:00  00:12:00
# 7       0000000_00000020240221085923_0003_IMP.mp4  00:13:00  00:13:00
# 8       0000000_00000020240221085923_0003_IMP.mp4  00:13:00  00:13:00
# 9           0000000_00000020240508114229_0002.mp4  00:02:00  00:04:00
# 10          0000000_00000020240508114229_0002.mp4  00:05:00  00:05:00
# 11          0000000_00000020240508114229_0002.mp4  00:07:00  00:07:00
# 12          0000000_00000020240508132920_0006.mp4  00:00:00  00:00:00
# 13          0000000_00000020240508132920_0006.mp4  00:01:00  00:01:00
# 14                      2_5395803543229709215.mp4  00:00:00  00:00:00
# 15                      2_5395803543229709215.mp4  00:02:00  00:02:02
# 16                      2_5395803543229709215.mp4  00:02:00  00:02:00
# 17                      2_5395803543229709215.mp4  00:02:00  00:02:00
# 18                      2_5395803543229709215.mp4  00:03:00  00:06:00
# 19                      2_5395803543229709215.mp4  00:11:00  00:11:00
# 20                      2_5395803543229709215.mp4  00:12:00  00:12:00
# 21                      2_5395803543229709261.mp4  00:01:43  00:01:46
# 22                      2_5395803543229709728.mp4  00:01:20  00:01:44
# 23                      2_5395803543229709828.mp4  00:04:38  00:04:58
# 24                      2_5395803543229709828.mp4  00:05:08  00:05:35
# 25                        VID_20240304_095112.mp4  00:21:00  00:22:00
# 26                        VID_20240304_095352.mp4  00:07:00  00:09:00
# 27                        VID_20240304_095423.mp4  00:03:00  00:04:00
# 28                        VID_20240311_154731.mp4  00:00:00  00:00:00
# 29                        VID_20240311_154731.mp4  00:00:00  00:00:00
# 30                        VID_20240311_154921.mp4  00:00:01  00:00:02
# 31                        VID-20240301-WA0022.mp4  00:00:20  00:00:26
# 32                        VID-20240301-WA0022.mp4  00:00:54  00:00:57
# 33                        VID-20240301-WA0023.mp4  00:02:00  00:02:00
#
#                                           description
# 0            Близко стоит к путям при движении поезда
# 1        Встал на подножку до полной остановки поезда
# 2                     Стоит возле поезда при стыковке
# 3                                     Залез под поезд
# 4            Близко стоит к путям при движении поезда
# 5                   достает башмак, залезая под поезд
# 6        Встал на подножку до полной остановки поезда
# 7                 Стоит возле поезда при его движении
# 8                                     Залез под поезд
# 9           стоит слишком близко к поезду движущемуся
# 10                вставляет башмак, залезая под поезд
# 11                  достает башмак, залезая под поезд
# 12                вставляет башмак, залезая под поезд
# 13                вставляет башмак, залезая под поезд
# 14                               нету букв на желетке
# 15                  достает башмак, залезая под поезд
# 16                вставляет башмак, залезая под поезд
# 17                  достает башмак, залезая под поезд
# 18                               катается на подножке
# 19  бегает, а еще не видно буквы на жилетке из-за ...
# 20                                 залезает под вагон
# 21                  достает башмак, залезая под поезд
# 22                                          нет формы
# 23                                    Залез под поезд
# 24                                    Залез под поезд
# 25                               нету букв на желетке
# 26                                    Залез под поезд
# 27                               нету букв на желетке
# 28                               нету букв на желетке
# 29                               нету букв на желетке
# 30                              прошел между вагонами
# 31                                    Залез под поезд
# 32                                    Залез под поезд
# 33                                 залезает под поезд

# %%
SAVING_FRAMES_PER_SECOND = 1 # кол-во кадров  в секунду
DELTA = 5 # отступаем до начала нарушения 5 сек

# %%
# info_df = info_df.head()

# %%
save_result_path = 'images'


image_result_info = pd.DataFrame()

for vi, f in tqdm(enumerate(info_df.videofile.unique()), total=info_df.shape[0]):
    temp = info_df[info_df.videofile==f]#.reset_index(drop=True)
    video_file = f'train/{f}'    
    file_names_df = main(video_file, f, vi, temp, DELTA, save_result_path)   
    image_result_info = pd.concat([image_result_info, file_names_df], ignore_index=True)
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# video_0_frame_0-00-55.02_flag_0_violation_0.jpg
# video_0_frame_0-00-56.02_flag_0_violation_0.jpg
# video_0_frame_0-00-57.02_flag_0_violation_0.jpg
# video_0_frame_0-00-58.02_flag_0_violation_0.jpg
# video_0_frame_0-00-59.03_flag_0_violation_0.jpg
# video_0_frame_0-05-55.02_flag_0_violation_1.jpg
# video_0_frame_0-05-56.02_flag_0_violation_1.jpg
# video_0_frame_0-05-57.02_flag_0_violation_1.jpg
# video_0_frame_0-05-58.02_flag_0_violation_1.jpg
# video_0_frame_0-05-59.03_flag_0_violation_1.jpg
# video_0_frame_0-06-00.03_flag_1_violation_1.jpg
# video_0_frame_0-06-01.03_flag_1_violation_1.jpg
# video_0_frame_0-06-02.03_flag_1_violation_1.jpg
# video_0_frame_0-06-03.03_flag_1_violation_1.jpg
# video_0_frame_0-06-04.03_flag_1_violation_1.jpg
# video_0_frame_0-06-05.03_flag_1_violation_1.jpg
# video_0_frame_0-06-06.03_flag_1_violation_1.jpg
# video_0_frame_0-06-07.03_flag_1_violation_1.jpg
# video_0_frame_0-06-08.00_flag_1_violation_1.jpg
# video_0_frame_0-06-09.00_flag_1_violation_1.jpg
# video_0_frame_0-06-10.00_flag_1_violation_1.jpg
# video_0_frame_0-06-11.00_flag_1_violation_1.jpg
# video_0_frame_0-06-12.00_flag_1_violation_1.jpg
# video_0_frame_0-06-13.01_flag_1_violation_1.jpg
# video_0_frame_0-06-14.01_flag_1_violation_1.jpg
# video_0_frame_0-06-15.01_flag_1_violation_1.jpg
# video_0_frame_0-06-16.01_flag_1_violation_1.jpg
# video_0_frame_0-06-17.01_flag_1_violation_1.jpg
# video_0_frame_0-06-18.01_flag_1_violation_1.jpg
# video_0_frame_0-06-19.01_flag_1_violation_1.jpg
# video_0_frame_0-06-20.01_flag_1_violation_1.jpg
# video_0_frame_0-06-21.01_flag_1_violation_1.jpg
# video_0_frame_0-06-22.01_flag_1_violation_1.jpg
# video_0_frame_0-06-23.02_flag_1_violation_1.jpg
# video_0_frame_0-06-24.02_flag_1_violation_1.jpg
# video_0_frame_0-06-25.02_flag_1_violation_1.jpg
# video_0_frame_0-06-26.02_flag_1_violation_1.jpg
# video_0_frame_0-06-27.02_flag_1_violation_1.jpg
# video_0_frame_0-06-28.02_flag_1_violation_1.jpg
# video_0_frame_0-06-29.02_flag_1_violation_1.jpg
# video_0_frame_0-06-30.02_flag_1_violation_1.jpg
# video_0_frame_0-06-31.02_flag_1_violation_1.jpg
# video_0_frame_0-06-32.02_flag_1_violation_1.jpg
# video_0_frame_0-06-33.03_flag_1_violation_1.jpg
# video_0_frame_0-06-34.03_flag_1_violation_1.jpg
# video_0_frame_0-06-35.03_flag_1_violation_1.jpg
# video_0_frame_0-06-36.03_flag_1_violation_1.jpg
# video_0_frame_0-06-37.03_flag_1_violation_1.jpg
# video_0_frame_0-06-38.03_flag_1_violation_1.jpg
# video_0_frame_0-06-39.03_flag_1_violation_1.jpg
# video_0_frame_0-06-40.03_flag_1_violation_1.jpg
# video_0_frame_0-06-41.00_flag_1_violation_1.jpg
# video_0_frame_0-06-42.00_flag_1_violation_1.jpg
# video_0_frame_0-06-43.00_flag_1_violation_1.jpg
# video_0_frame_0-06-44.00_flag_1_violation_1.jpg
# video_0_frame_0-06-45.00_flag_1_violation_1.jpg
# video_0_frame_0-06-46.01_flag_1_violation_1.jpg
# video_0_frame_0-06-47.01_flag_1_violation_1.jpg
# video_0_frame_0-06-48.01_flag_1_violation_1.jpg
# video_0_frame_0-06-49.01_flag_1_violation_1.jpg
# video_0_frame_0-06-50.01_flag_1_violation_1.jpg
# video_0_frame_0-06-51.01_flag_1_violation_1.jpg
# video_0_frame_0-06-52.01_flag_1_violation_1.jpg
# video_0_frame_0-06-53.01_flag_1_violation_1.jpg
# video_0_frame_0-06-54.01_flag_1_violation_1.jpg
# video_0_frame_0-06-55.01_flag_1_violation_1.jpg
# video_0_frame_0-06-56.02_flag_1_violation_1.jpg
# video_0_frame_0-06-57.02_flag_1_violation_1.jpg
# video_0_frame_0-06-58.02_flag_1_violation_1.jpg
# video_0_frame_0-06-59.02_flag_1_violation_1.jpg
# video_0_frame_0-07-00.02_flag_1_violation_1.jpg
# video_0_frame_0-07-01.02_flag_1_violation_1.jpg
# video_0_frame_0-07-02.02_flag_1_violation_1.jpg
# video_0_frame_0-07-03.02_flag_1_violation_1.jpg
# video_0_frame_0-07-04.02_flag_1_violation_1.jpg
# video_0_frame_0-07-05.02_flag_1_violation_1.jpg
# video_0_frame_0-07-06.03_flag_1_violation_1.jpg
# video_0_frame_0-07-07.03_flag_1_violation_1.jpg
# video_0_frame_0-07-08.03_flag_1_violation_1.jpg
# video_0_frame_0-07-09.03_flag_1_violation_1.jpg
# video_0_frame_0-07-10.03_flag_1_violation_1.jpg
# video_0_frame_0-07-11.03_flag_1_violation_1.jpg
# video_0_frame_0-07-12.03_flag_1_violation_1.jpg
# video_0_frame_0-07-13.03_flag_1_violation_1.jpg
# video_0_frame_0-07-14.00_flag_1_violation_1.jpg
# video_0_frame_0-07-15.00_flag_1_violation_1.jpg
# video_0_frame_0-07-16.00_flag_1_violation_1.jpg
# video_0_frame_0-07-17.00_flag_1_violation_1.jpg
# video_0_frame_0-07-18.00_flag_1_violation_1.jpg
# video_0_frame_0-07-19.01_flag_1_violation_1.jpg
# video_0_frame_0-07-20.01_flag_1_violation_1.jpg
# video_0_frame_0-07-21.01_flag_1_violation_1.jpg
# video_0_frame_0-07-22.01_flag_1_violation_1.jpg
# video_0_frame_0-07-23.01_flag_1_violation_1.jpg
# video_0_frame_0-07-24.01_flag_1_violation_1.jpg
# video_0_frame_0-07-25.01_flag_1_violation_1.jpg
# video_0_frame_0-07-26.01_flag_1_violation_1.jpg
# video_0_frame_0-07-27.01_flag_1_violation_1.jpg
# video_0_frame_0-07-28.01_flag_1_violation_1.jpg
# video_0_frame_0-07-29.02_flag_1_violation_1.jpg
# video_0_frame_0-07-30.02_flag_1_violation_1.jpg
# video_0_frame_0-07-31.02_flag_1_violation_1.jpg
# video_0_frame_0-07-32.02_flag_1_violation_1.jpg
# video_0_frame_0-07-33.02_flag_1_violation_1.jpg
# video_0_frame_0-07-34.02_flag_1_violation_1.jpg
# video_0_frame_0-07-35.02_flag_1_violation_1.jpg
# video_0_frame_0-07-36.02_flag_1_violation_1.jpg
# video_0_frame_0-07-37.02_flag_1_violation_1.jpg
# video_0_frame_0-07-38.02_flag_1_violation_1.jpg
# video_0_frame_0-07-39.03_flag_1_violation_1.jpg
# video_0_frame_0-07-40.03_flag_1_violation_1.jpg
# video_0_frame_0-07-41.03_flag_1_violation_1.jpg
# video_0_frame_0-07-42.03_flag_1_violation_1.jpg
# video_0_frame_0-07-43.03_flag_1_violation_1.jpg
# video_0_frame_0-07-44.03_flag_1_violation_1.jpg
# video_0_frame_0-07-45.03_flag_1_violation_1.jpg
# video_0_frame_0-07-46.03_flag_1_violation_1.jpg
# video_0_frame_0-07-47.03_flag_1_violation_1.jpg
# video_0_frame_0-07-48.00_flag_1_violation_1.jpg
# video_0_frame_0-07-49.00_flag_1_violation_1.jpg
# video_0_frame_0-07-50.00_flag_1_violation_1.jpg
# video_0_frame_0-07-51.00_flag_1_violation_1.jpg
# video_0_frame_0-07-52.00_flag_1_violation_1.jpg
# video_0_frame_0-07-53.01_flag_1_violation_1.jpg
# video_0_frame_0-07-54.01_flag_1_violation_1.jpg
# video_0_frame_0-07-55.01_flag_1_violation_1.jpg
# video_0_frame_0-07-56.01_flag_1_violation_1.jpg
# video_0_frame_0-07-57.01_flag_1_violation_1.jpg
# video_0_frame_0-07-58.01_flag_1_violation_1.jpg
# video_0_frame_0-07-59.01_flag_1_violation_1.jpg
# video_0_frame_0-08-00.01_flag_1_violation_1.jpg
# video_0_frame_0-08-01.01_flag_1_violation_1.jpg
# video_0_frame_0-08-02.01_flag_1_violation_1.jpg
# video_0_frame_0-08-03.02_flag_1_violation_1.jpg
# video_0_frame_0-08-04.02_flag_1_violation_1.jpg
# video_0_frame_0-08-05.02_flag_1_violation_1.jpg
# video_0_frame_0-08-06.02_flag_1_violation_1.jpg
# video_0_frame_0-08-07.02_flag_1_violation_1.jpg
# video_0_frame_0-08-08.02_flag_1_violation_1.jpg
# video_0_frame_0-08-09.02_flag_1_violation_1.jpg
# video_0_frame_0-08-10.02_flag_1_violation_1.jpg
# video_0_frame_0-08-11.02_flag_1_violation_1.jpg
# video_0_frame_0-08-12.02_flag_1_violation_1.jpg
# video_0_frame_0-08-13.03_flag_1_violation_1.jpg
# video_0_frame_0-08-14.03_flag_1_violation_1.jpg
# video_0_frame_0-08-15.03_flag_1_violation_1.jpg
# video_0_frame_0-08-16.03_flag_1_violation_1.jpg
# video_0_frame_0-08-17.03_flag_1_violation_1.jpg
# video_0_frame_0-08-18.03_flag_1_violation_1.jpg
# video_0_frame_0-08-19.03_flag_1_violation_1.jpg
# video_0_frame_0-08-20.03_flag_1_violation_1.jpg
# video_0_frame_0-08-21.00_flag_1_violation_1.jpg
# video_0_frame_0-08-22.00_flag_1_violation_1.jpg
# video_0_frame_0-08-23.00_flag_1_violation_1.jpg
# video_0_frame_0-08-24.00_flag_1_violation_1.jpg
# video_0_frame_0-08-25.00_flag_1_violation_1.jpg
# video_0_frame_0-08-26.01_flag_1_violation_1.jpg
# video_0_frame_0-08-27.01_flag_1_violation_1.jpg
# video_0_frame_0-08-28.01_flag_1_violation_1.jpg
# video_0_frame_0-08-29.01_flag_1_violation_1.jpg
# video_0_frame_0-08-30.01_flag_1_violation_1.jpg
# video_0_frame_0-08-31.01_flag_1_violation_1.jpg
# video_0_frame_0-08-32.01_flag_1_violation_1.jpg
# video_0_frame_0-08-33.01_flag_1_violation_1.jpg
# video_0_frame_0-08-34.01_flag_1_violation_1.jpg
# video_0_frame_0-08-35.01_flag_1_violation_1.jpg
# video_0_frame_0-08-36.02_flag_1_violation_1.jpg
# video_0_frame_0-08-37.02_flag_1_violation_1.jpg
# video_0_frame_0-08-38.02_flag_1_violation_1.jpg
# video_0_frame_0-08-39.02_flag_1_violation_1.jpg
# video_0_frame_0-08-40.02_flag_1_violation_1.jpg
# video_0_frame_0-08-41.02_flag_1_violation_1.jpg
# video_0_frame_0-08-42.02_flag_1_violation_1.jpg
# video_0_frame_0-08-43.02_flag_1_violation_1.jpg
# video_0_frame_0-08-44.02_flag_1_violation_1.jpg
# video_0_frame_0-08-45.02_flag_1_violation_1.jpg
# video_0_frame_0-08-46.03_flag_1_violation_1.jpg
# video_0_frame_0-08-47.03_flag_1_violation_1.jpg
# video_0_frame_0-08-48.03_flag_1_violation_1.jpg
# video_0_frame_0-08-49.03_flag_1_violation_1.jpg
# video_0_frame_0-08-50.03_flag_1_violation_1.jpg
# video_0_frame_0-08-51.03_flag_1_violation_1.jpg
# video_0_frame_0-08-52.03_flag_1_violation_1.jpg
# video_0_frame_0-08-53.03_flag_1_violation_1.jpg
# video_0_frame_0-08-54.00_flag_1_violation_1.jpg
# video_0_frame_0-08-55.00_flag_1_violation_1.jpg
# video_0_frame_0-08-56.00_flag_1_violation_1.jpg
# video_0_frame_0-08-57.00_flag_1_violation_1.jpg
# video_0_frame_0-08-58.00_flag_1_violation_1.jpg
# video_0_frame_0-08-59.01_flag_1_violation_1.jpg
# video_0_frame_0-09-00.01_flag_1_violation_1.jpg
# video_0_frame_0-09-01.01_flag_1_violation_1.jpg
# video_0_frame_0-09-02.01_flag_1_violation_1.jpg
# video_0_frame_0-09-03.01_flag_1_violation_1.jpg
# video_0_frame_0-09-04.01_flag_1_violation_1.jpg
# video_0_frame_0-09-05.01_flag_1_violation_1.jpg
# video_0_frame_0-09-06.01_flag_1_violation_1.jpg
# video_0_frame_0-09-07.01_flag_1_violation_1.jpg
# video_0_frame_0-09-08.01_flag_1_violation_1.jpg
# video_0_frame_0-09-09.02_flag_1_violation_1.jpg
# video_0_frame_0-09-10.02_flag_1_violation_1.jpg
# video_0_frame_0-09-11.02_flag_1_violation_1.jpg
# video_0_frame_0-09-12.02_flag_1_violation_1.jpg
# video_0_frame_0-09-13.02_flag_1_violation_1.jpg
# video_0_frame_0-09-14.02_flag_1_violation_1.jpg
# video_0_frame_0-09-15.02_flag_1_violation_1.jpg
# video_0_frame_0-09-16.02_flag_1_violation_1.jpg
# video_0_frame_0-09-17.02_flag_1_violation_1.jpg
# video_0_frame_0-09-18.02_flag_1_violation_1.jpg
# video_0_frame_0-09-19.03_flag_1_violation_1.jpg
# video_0_frame_0-09-20.03_flag_1_violation_1.jpg
# video_0_frame_0-09-21.03_flag_1_violation_1.jpg
# video_0_frame_0-09-22.03_flag_1_violation_1.jpg
# video_0_frame_0-09-23.03_flag_1_violation_1.jpg
# video_0_frame_0-09-24.03_flag_1_violation_1.jpg
# video_0_frame_0-09-25.03_flag_1_violation_1.jpg
# video_0_frame_0-09-26.03_flag_1_violation_1.jpg
# video_0_frame_0-09-27.03_flag_1_violation_1.jpg
# video_0_frame_0-09-28.00_flag_1_violation_1.jpg
# video_0_frame_0-09-29.00_flag_1_violation_1.jpg
# video_0_frame_0-09-30.00_flag_1_violation_1.jpg
# video_0_frame_0-09-31.00_flag_1_violation_1.jpg
# video_0_frame_0-09-32.00_flag_1_violation_1.jpg
# video_0_frame_0-09-33.01_flag_1_violation_1.jpg
# video_0_frame_0-09-34.01_flag_1_violation_1.jpg
# video_0_frame_0-09-35.01_flag_1_violation_1.jpg
# video_0_frame_0-09-36.01_flag_1_violation_1.jpg
# video_0_frame_0-09-37.01_flag_1_violation_1.jpg
# video_0_frame_0-09-38.01_flag_1_violation_1.jpg
# video_0_frame_0-09-39.01_flag_1_violation_1.jpg
# video_0_frame_0-09-40.01_flag_1_violation_1.jpg
# video_0_frame_0-09-41.01_flag_1_violation_1.jpg
# video_0_frame_0-09-42.01_flag_1_violation_1.jpg
# video_0_frame_0-09-43.02_flag_1_violation_1.jpg
# video_0_frame_0-09-44.02_flag_1_violation_1.jpg
# video_0_frame_0-09-45.02_flag_1_violation_1.jpg
# video_0_frame_0-09-46.02_flag_1_violation_1.jpg
# video_0_frame_0-09-47.02_flag_1_violation_1.jpg
# video_0_frame_0-09-48.02_flag_1_violation_1.jpg
# video_0_frame_0-09-49.02_flag_1_violation_1.jpg
# video_0_frame_0-09-50.02_flag_1_violation_1.jpg
# video_0_frame_0-09-51.02_flag_1_violation_1.jpg
# video_0_frame_0-09-52.02_flag_1_violation_1.jpg
# video_0_frame_0-09-53.03_flag_1_violation_1.jpg
# video_0_frame_0-09-54.03_flag_1_violation_1.jpg
# video_0_frame_0-09-55.03_flag_1_violation_1.jpg
# video_0_frame_0-09-56.03_flag_1_violation_1.jpg
# video_0_frame_0-09-57.03_flag_1_violation_1.jpg
# video_0_frame_0-09-58.03_flag_1_violation_1.jpg
# video_0_frame_0-09-59.03_flag_1_violation_1.jpg
# video_0_frame_0-10-00.03_flag_1_violation_1.jpg
# video_0_frame_0-10-01.00_flag_1_violation_1.jpg
# video_0_frame_0-10-02.00_flag_1_violation_1.jpg
# video_0_frame_0-10-03.00_flag_1_violation_1.jpg
# video_0_frame_0-10-04.00_flag_1_violation_1.jpg
# video_0_frame_0-10-05.00_flag_1_violation_1.jpg
# video_0_frame_0-10-06.01_flag_1_violation_1.jpg
# video_0_frame_0-10-07.01_flag_1_violation_1.jpg
# video_0_frame_0-10-08.01_flag_1_violation_1.jpg
# video_0_frame_0-10-09.01_flag_1_violation_1.jpg
# video_0_frame_0-10-10.01_flag_1_violation_1.jpg
# video_0_frame_0-10-11.01_flag_1_violation_1.jpg
# video_0_frame_0-10-12.01_flag_1_violation_1.jpg
# video_0_frame_0-10-13.01_flag_1_violation_1.jpg
# video_0_frame_0-10-14.01_flag_1_violation_1.jpg
# video_0_frame_0-10-15.01_flag_1_violation_1.jpg
# video_0_frame_0-10-16.02_flag_1_violation_1.jpg
# video_0_frame_0-10-17.02_flag_1_violation_1.jpg
# video_0_frame_0-10-18.02_flag_1_violation_1.jpg
# video_0_frame_0-10-19.02_flag_1_violation_1.jpg
# video_0_frame_0-10-20.02_flag_1_violation_1.jpg
# video_0_frame_0-10-21.02_flag_1_violation_1.jpg
# video_0_frame_0-10-22.02_flag_1_violation_1.jpg
# video_0_frame_0-10-23.02_flag_1_violation_1.jpg
# video_0_frame_0-10-24.02_flag_1_violation_1.jpg
# video_0_frame_0-10-25.02_flag_1_violation_1.jpg
# video_0_frame_0-10-26.03_flag_1_violation_1.jpg
# video_0_frame_0-10-27.03_flag_1_violation_1.jpg
# video_0_frame_0-10-28.03_flag_1_violation_1.jpg
# video_0_frame_0-10-29.03_flag_1_violation_1.jpg
# video_0_frame_0-10-30.03_flag_1_violation_1.jpg
# video_0_frame_0-10-31.03_flag_1_violation_1.jpg
# video_0_frame_0-10-32.03_flag_1_violation_1.jpg
# video_0_frame_0-10-33.03_flag_1_violation_1.jpg
# video_0_frame_0-10-34.00_flag_1_violation_1.jpg
# video_0_frame_0-10-35.00_flag_1_violation_1.jpg
# video_0_frame_0-10-36.00_flag_1_violation_1.jpg
# video_0_frame_0-10-37.00_flag_1_violation_1.jpg
# video_0_frame_0-10-38.00_flag_1_violation_1.jpg
# video_0_frame_0-10-39.01_flag_1_violation_1.jpg
# video_0_frame_0-10-40.01_flag_1_violation_1.jpg
# video_0_frame_0-10-41.01_flag_1_violation_1.jpg
# video_0_frame_0-10-42.01_flag_1_violation_1.jpg
# video_0_frame_0-10-43.01_flag_1_violation_1.jpg
# video_0_frame_0-10-44.01_flag_1_violation_1.jpg
# video_0_frame_0-10-45.01_flag_1_violation_1.jpg
# video_0_frame_0-10-46.01_flag_1_violation_1.jpg
# video_0_frame_0-10-47.01_flag_1_violation_1.jpg
# video_0_frame_0-10-48.01_flag_1_violation_1.jpg
# video_0_frame_0-10-49.02_flag_1_violation_1.jpg
# video_0_frame_0-10-50.02_flag_1_violation_1.jpg
# video_0_frame_0-10-51.02_flag_1_violation_1.jpg
# video_0_frame_0-10-52.02_flag_1_violation_1.jpg
# video_0_frame_0-10-53.02_flag_1_violation_1.jpg
# video_0_frame_0-10-54.02_flag_1_violation_1.jpg
# video_0_frame_0-10-55.02_flag_1_violation_1.jpg
# video_0_frame_0-10-56.02_flag_1_violation_1.jpg
# video_0_frame_0-10-57.02_flag_1_violation_1.jpg
# video_0_frame_0-10-58.02_flag_1_violation_1.jpg
# video_0_frame_0-10-59.03_flag_1_violation_1.jpg
# video_0_frame_0-11-00.03_flag_1_violation_1.jpg
# video_0_frame_0-11-01.03_flag_1_violation_1.jpg
# video_0_frame_0-11-02.03_flag_1_violation_1.jpg
# video_0_frame_0-11-03.03_flag_1_violation_1.jpg
# video_0_frame_0-11-04.03_flag_1_violation_1.jpg
# video_0_frame_0-11-05.03_flag_1_violation_1.jpg
# video_0_frame_0-11-06.03_flag_1_violation_1.jpg
# video_0_frame_0-11-07.03_flag_1_violation_1.jpg
# video_0_frame_0-11-08.00_flag_1_violation_1.jpg
# video_0_frame_0-11-09.00_flag_1_violation_1.jpg
# video_0_frame_0-11-10.00_flag_1_violation_1.jpg
# video_0_frame_0-11-11.00_flag_1_violation_1.jpg
# video_0_frame_0-11-12.00_flag_1_violation_1.jpg
# video_0_frame_0-11-13.01_flag_1_violation_1.jpg
# video_0_frame_0-11-14.01_flag_1_violation_1.jpg
# video_0_frame_0-11-15.01_flag_1_violation_1.jpg
# video_0_frame_0-11-16.01_flag_1_violation_1.jpg
# video_0_frame_0-11-17.01_flag_1_violation_1.jpg
# video_0_frame_0-11-18.01_flag_1_violation_1.jpg
# video_0_frame_0-11-19.01_flag_1_violation_1.jpg
# video_0_frame_0-11-20.01_flag_1_violation_1.jpg
# video_0_frame_0-11-21.01_flag_1_violation_1.jpg
# video_0_frame_0-11-22.01_flag_1_violation_1.jpg
# video_0_frame_0-11-23.02_flag_1_violation_1.jpg
# video_0_frame_0-11-24.02_flag_1_violation_1.jpg
# video_0_frame_0-11-25.02_flag_1_violation_1.jpg
# video_0_frame_0-11-26.02_flag_1_violation_1.jpg
# video_0_frame_0-11-27.02_flag_1_violation_1.jpg
# video_0_frame_0-11-28.02_flag_1_violation_1.jpg
# video_0_frame_0-11-29.02_flag_1_violation_1.jpg
# video_0_frame_0-11-30.02_flag_1_violation_1.jpg
# video_0_frame_0-11-31.02_flag_1_violation_1.jpg
# video_0_frame_0-11-32.02_flag_1_violation_1.jpg
# video_0_frame_0-11-33.03_flag_1_violation_1.jpg
# video_0_frame_0-11-34.03_flag_1_violation_1.jpg
# video_0_frame_0-11-35.03_flag_1_violation_1.jpg
# video_0_frame_0-11-36.03_flag_1_violation_1.jpg
# video_0_frame_0-11-37.03_flag_1_violation_1.jpg
# video_0_frame_0-11-38.03_flag_1_violation_1.jpg
# video_0_frame_0-11-39.03_flag_1_violation_1.jpg
# video_0_frame_0-11-40.03_flag_1_violation_1.jpg
# video_0_frame_0-11-41.00_flag_1_violation_1.jpg
# video_0_frame_0-11-42.00_flag_1_violation_1.jpg
# video_0_frame_0-11-43.00_flag_1_violation_1.jpg
# video_0_frame_0-11-44.00_flag_1_violation_1.jpg
# video_0_frame_0-11-45.00_flag_1_violation_1.jpg
# video_0_frame_0-11-46.01_flag_1_violation_1.jpg
# video_0_frame_0-11-47.01_flag_1_violation_1.jpg
# video_0_frame_0-11-48.01_flag_1_violation_1.jpg
# video_0_frame_0-11-49.01_flag_1_violation_1.jpg
# video_0_frame_0-11-50.01_flag_1_violation_1.jpg
# video_0_frame_0-11-51.01_flag_1_violation_1.jpg
# video_0_frame_0-11-52.01_flag_1_violation_1.jpg
# video_0_frame_0-11-53.01_flag_1_violation_1.jpg
# video_0_frame_0-11-54.01_flag_1_violation_1.jpg
# video_0_frame_0-11-55.01_flag_1_violation_1.jpg
# video_0_frame_0-11-56.02_flag_1_violation_1.jpg
# video_0_frame_0-11-57.02_flag_1_violation_1.jpg
# video_0_frame_0-11-58.02_flag_1_violation_1.jpg
# video_0_frame_0-11-59.02_flag_1_violation_1.jpg
# video_0_frame_0-12-00.02_flag_1_violation_1.jpg
# video_0_frame_0-12-01.02_flag_1_violation_1.jpg
# video_0_frame_0-12-02.02_flag_1_violation_1.jpg
# video_0_frame_0-12-03.02_flag_1_violation_1.jpg
# video_0_frame_0-12-04.02_flag_1_violation_1.jpg
# video_0_frame_0-12-05.02_flag_1_violation_1.jpg
# video_0_frame_0-12-06.03_flag_1_violation_1.jpg
# video_0_frame_0-12-07.03_flag_1_violation_1.jpg
# video_0_frame_0-12-08.03_flag_1_violation_1.jpg
# video_0_frame_0-12-09.03_flag_1_violation_1.jpg
# video_0_frame_0-12-10.03_flag_1_violation_1.jpg
# video_0_frame_0-12-11.03_flag_1_violation_1.jpg
# video_0_frame_0-12-12.03_flag_1_violation_1.jpg
# video_0_frame_0-12-13.03_flag_1_violation_1.jpg
# video_0_frame_0-12-14.03_flag_1_violation_1.jpg
# video_0_frame_0-12-15.00_flag_1_violation_1.jpg
# video_0_frame_0-12-16.00_flag_1_violation_1.jpg
# video_0_frame_0-12-17.00_flag_1_violation_1.jpg
# video_0_frame_0-12-18.00_flag_1_violation_1.jpg
# video_0_frame_0-12-19.00_flag_1_violation_1.jpg
# video_0_frame_0-12-20.01_flag_1_violation_1.jpg
# video_0_frame_0-12-21.01_flag_1_violation_1.jpg
# video_0_frame_0-12-22.01_flag_1_violation_1.jpg
# video_0_frame_0-12-23.01_flag_1_violation_1.jpg
# video_0_frame_0-12-24.01_flag_1_violation_1.jpg
# video_0_frame_0-12-25.01_flag_1_violation_1.jpg
# video_0_frame_0-12-26.01_flag_1_violation_1.jpg
# video_0_frame_0-12-27.01_flag_1_violation_1.jpg
# video_0_frame_0-12-28.01_flag_1_violation_1.jpg
# video_0_frame_0-12-29.01_flag_1_violation_1.jpg
# video_0_frame_0-12-30.02_flag_1_violation_1.jpg
# video_0_frame_0-12-31.02_flag_1_violation_1.jpg
# video_0_frame_0-12-32.02_flag_1_violation_1.jpg
# video_0_frame_0-12-33.02_flag_1_violation_1.jpg
# video_0_frame_0-12-34.02_flag_1_violation_1.jpg
# video_0_frame_0-12-35.02_flag_1_violation_1.jpg
# video_0_frame_0-12-36.02_flag_1_violation_1.jpg
# video_0_frame_0-12-37.02_flag_1_violation_1.jpg
# video_0_frame_0-12-38.02_flag_1_violation_1.jpg
# video_0_frame_0-12-39.02_flag_1_violation_1.jpg
# video_0_frame_0-12-40.03_flag_1_violation_1.jpg
# video_0_frame_0-12-41.03_flag_1_violation_1.jpg
# video_0_frame_0-12-42.03_flag_1_violation_1.jpg
# video_0_frame_0-12-43.03_flag_1_violation_1.jpg
# video_0_frame_0-12-44.03_flag_1_violation_1.jpg
# video_0_frame_0-12-45.03_flag_1_violation_1.jpg
# video_0_frame_0-12-46.03_flag_1_violation_1.jpg
# video_0_frame_0-12-47.03_flag_1_violation_1.jpg
# video_0_frame_0-12-48.00_flag_1_violation_1.jpg
# video_0_frame_0-12-49.00_flag_1_violation_1.jpg
# video_0_frame_0-12-50.00_flag_1_violation_1.jpg
# video_0_frame_0-12-51.00_flag_1_violation_1.jpg
# video_0_frame_0-12-52.00_flag_1_violation_1.jpg
# video_0_frame_0-12-53.01_flag_1_violation_1.jpg
# video_0_frame_0-12-54.01_flag_1_violation_1.jpg
# video_0_frame_0-12-55.01_flag_1_violation_1.jpg
# video_0_frame_0-12-56.01_flag_1_violation_1.jpg
# video_0_frame_0-12-57.01_flag_1_violation_1.jpg
# video_0_frame_0-12-58.01_flag_1_violation_1.jpg
# video_0_frame_0-12-59.01_flag_1_violation_1.jpg
# video_0_frame_0-13-00.01_flag_1_violation_1.jpg
# video_0_frame_0-13-01.01_flag_1_violation_1.jpg
# video_0_frame_0-13-02.01_flag_1_violation_1.jpg
# video_0_frame_0-13-03.02_flag_1_violation_1.jpg
# video_0_frame_0-13-04.02_flag_1_violation_1.jpg
# video_0_frame_0-13-05.02_flag_1_violation_1.jpg
# video_0_frame_0-13-06.02_flag_1_violation_1.jpg
# video_0_frame_0-13-07.02_flag_1_violation_1.jpg
# video_0_frame_0-13-08.02_flag_1_violation_1.jpg
# video_0_frame_0-13-09.02_flag_1_violation_1.jpg
# video_0_frame_0-13-10.02_flag_1_violation_1.jpg
# video_0_frame_0-13-11.02_flag_1_violation_1.jpg
# video_0_frame_0-13-12.02_flag_1_violation_1.jpg
# video_0_frame_0-13-13.03_flag_1_violation_1.jpg
# video_0_frame_0-13-14.03_flag_1_violation_1.jpg
# video_0_frame_0-13-15.03_flag_1_violation_1.jpg
# video_0_frame_0-13-16.03_flag_1_violation_1.jpg
# video_0_frame_0-13-17.03_flag_1_violation_1.jpg
# video_0_frame_0-13-18.03_flag_1_violation_1.jpg
# video_0_frame_0-13-19.03_flag_1_violation_1.jpg
# video_0_frame_0-13-20.03_flag_1_violation_1.jpg
# video_0_frame_0-13-21.00_flag_1_violation_1.jpg
# video_0_frame_0-13-22.00_flag_1_violation_1.jpg
# video_0_frame_0-13-23.00_flag_1_violation_1.jpg
# video_0_frame_0-13-24.00_flag_1_violation_1.jpg
# video_0_frame_0-13-25.00_flag_1_violation_1.jpg
# video_0_frame_0-13-26.01_flag_1_violation_1.jpg
# video_0_frame_0-13-27.01_flag_1_violation_1.jpg
# video_0_frame_0-13-28.01_flag_1_violation_1.jpg
# video_0_frame_0-13-29.01_flag_1_violation_1.jpg
# video_0_frame_0-13-30.01_flag_1_violation_1.jpg
# video_0_frame_0-13-31.01_flag_1_violation_1.jpg
# video_0_frame_0-13-32.01_flag_1_violation_1.jpg
# video_0_frame_0-13-33.01_flag_1_violation_1.jpg
# video_0_frame_0-13-34.01_flag_1_violation_1.jpg
# video_0_frame_0-13-35.01_flag_1_violation_1.jpg
# video_0_frame_0-13-36.02_flag_1_violation_1.jpg
# video_0_frame_0-13-37.02_flag_1_violation_1.jpg
# video_0_frame_0-13-38.02_flag_1_violation_1.jpg
# video_0_frame_0-13-39.02_flag_1_violation_1.jpg
# video_0_frame_0-13-40.02_flag_1_violation_1.jpg
# video_0_frame_0-13-41.02_flag_1_violation_1.jpg
# video_0_frame_0-13-42.02_flag_1_violation_1.jpg
# video_0_frame_0-13-43.02_flag_1_violation_1.jpg
# video_0_frame_0-13-44.02_flag_1_violation_1.jpg
# video_0_frame_0-13-45.02_flag_1_violation_1.jpg
# video_0_frame_0-13-46.03_flag_1_violation_1.jpg
# video_0_frame_0-13-47.03_flag_1_violation_1.jpg
# video_0_frame_0-13-48.03_flag_1_violation_1.jpg
# video_0_frame_0-13-49.03_flag_1_violation_1.jpg
# video_0_frame_0-13-50.03_flag_1_violation_1.jpg
# video_0_frame_0-13-51.03_flag_1_violation_1.jpg
# video_0_frame_0-13-52.03_flag_1_violation_1.jpg
# video_0_frame_0-13-53.03_flag_1_violation_1.jpg
# video_0_frame_0-13-54.03_flag_1_violation_1.jpg
# video_0_frame_0-13-55.00_flag_1_violation_1.jpg
# video_0_frame_0-13-56.00_flag_1_violation_1.jpg
# video_0_frame_0-13-57.00_flag_1_violation_1.jpg
# video_0_frame_0-13-58.00_flag_1_violation_1.jpg
# video_0_frame_0-13-59.00_flag_1_violation_1.jpg
# video_0_frame_0-14-00.01_flag_1_violation_1.jpg
# video_0_frame_0-14-01.01_flag_1_violation_1.jpg
# video_0_frame_0-14-02.01_flag_1_violation_1.jpg
# video_0_frame_0-14-03.01_flag_1_violation_1.jpg
# video_0_frame_0-14-04.01_flag_1_violation_1.jpg
# video_0_frame_0-14-05.01_flag_1_violation_1.jpg
# video_0_frame_0-14-06.01_flag_1_violation_1.jpg
# video_0_frame_0-14-07.01_flag_1_violation_1.jpg
# video_0_frame_0-14-08.01_flag_1_violation_1.jpg
# video_0_frame_0-14-09.01_flag_1_violation_1.jpg
# video_0_frame_0-14-10.02_flag_1_violation_1.jpg
# video_0_frame_0-14-11.02_flag_1_violation_1.jpg
# video_0_frame_0-14-12.02_flag_1_violation_1.jpg
# video_0_frame_0-14-13.02_flag_1_violation_1.jpg
# video_0_frame_0-14-14.02_flag_1_violation_1.jpg
# video_0_frame_0-14-15.02_flag_1_violation_1.jpg
# video_0_frame_0-14-16.02_flag_1_violation_1.jpg
# video_0_frame_0-14-17.02_flag_1_violation_1.jpg
# video_0_frame_0-14-18.02_flag_1_violation_1.jpg
# video_0_frame_0-14-19.02_flag_1_violation_1.jpg
# video_0_frame_0-14-20.03_flag_1_violation_1.jpg
# video_0_frame_0-14-21.03_flag_1_violation_1.jpg
# video_0_frame_0-14-22.03_flag_1_violation_1.jpg
# video_0_frame_0-14-23.03_flag_1_violation_1.jpg
# video_0_frame_0-14-24.03_flag_1_violation_1.jpg
# video_0_frame_0-14-25.03_flag_1_violation_1.jpg
# video_0_frame_0-14-26.03_flag_1_violation_1.jpg
# video_0_frame_0-14-27.03_flag_1_violation_1.jpg
# video_0_frame_0-14-28.00_flag_1_violation_1.jpg
# video_0_frame_0-14-29.00_flag_1_violation_1.jpg
# video_0_frame_0-14-30.00_flag_1_violation_1.jpg
# video_0_frame_0-14-31.00_flag_1_violation_1.jpg
# video_0_frame_0-14-32.00_flag_1_violation_1.jpg
# video_0_frame_0-14-33.01_flag_1_violation_1.jpg
# video_0_frame_0-14-34.01_flag_1_violation_1.jpg
# video_0_frame_0-14-35.01_flag_1_violation_1.jpg
# video_0_frame_0-14-36.01_flag_1_violation_1.jpg
# video_0_frame_0-14-37.01_flag_1_violation_1.jpg
# video_0_frame_0-14-38.01_flag_1_violation_1.jpg
# video_0_frame_0-14-39.01_flag_1_violation_1.jpg
# video_0_frame_0-14-40.01_flag_1_violation_1.jpg
# video_0_frame_0-14-41.01_flag_1_violation_1.jpg
# video_0_frame_0-14-42.01_flag_1_violation_1.jpg
# video_0_frame_0-14-43.02_flag_1_violation_1.jpg
# video_0_frame_0-14-44.02_flag_1_violation_1.jpg
# video_0_frame_0-14-45.02_flag_1_violation_1.jpg
# video_0_frame_0-14-46.02_flag_1_violation_1.jpg
# video_0_frame_0-14-47.02_flag_1_violation_1.jpg
# video_0_frame_0-14-48.02_flag_1_violation_1.jpg
# video_0_frame_0-14-49.02_flag_1_violation_1.jpg
# video_0_frame_0-14-50.02_flag_1_violation_1.jpg
# video_0_frame_0-14-51.02_flag_1_violation_1.jpg
# video_0_frame_0-14-52.02_flag_1_violation_1.jpg
# video_0_frame_0-14-53.03_flag_1_violation_1.jpg
# video_0_frame_0-14-54.03_flag_1_violation_1.jpg
# video_0_frame_0-14-55.03_flag_1_violation_1.jpg
# video_0_frame_0-14-56.03_flag_1_violation_1.jpg
# video_0_frame_0-14-57.03_flag_1_violation_1.jpg
# video_0_frame_0-14-58.03_flag_1_violation_1.jpg
# video_0_frame_0-14-59.03_flag_1_violation_1.jpg
#  20%|██        | 1/5 [04:08<16:35, 248.78s/it]
# video_0_frame_0-15-00.03_flag_1_violation_1.jpg
# video_1_frame_0-06-55.01_flag_0_violation_4.jpg
# video_1_frame_0-06-56.02_flag_0_violation_4.jpg
# video_1_frame_0-06-57.02_flag_0_violation_4.jpg
# video_1_frame_0-06-58.02_flag_0_violation_4.jpg
#  40%|████      | 2/5 [05:40<08:30, 170.01s/it]
# video_1_frame_0-06-59.02_flag_0_violation_4.jpg

# %%
image_result_info.to_csv('image_result_info.csv')

# %%
image_result_info
# Out:
#                                         video_name  video_num  \
# 0    0000000_00000020240221082923_0001_IMP (1).mp4          0
# 1    0000000_00000020240221082923_0001_IMP (1).mp4          0
# 2    0000000_00000020240221082923_0001_IMP (1).mp4          0
# 3    0000000_00000020240221082923_0001_IMP (1).mp4          0
# 4    0000000_00000020240221082923_0001_IMP (1).mp4          0
# ..                                             ...        ...
# 551      0000000_00000020240221084423_0002_IMP.mp4          1
# 552      0000000_00000020240221084423_0002_IMP.mp4          1
# 553      0000000_00000020240221084423_0002_IMP.mp4          1
# 554      0000000_00000020240221084423_0002_IMP.mp4          1
# 555      0000000_00000020240221084423_0002_IMP.mp4          1
#
#                                           image_name frame_duration  target  \
# 0    video_0_frame_0-00-55.02_flag_0_violation_0.jpg     0-00-55.02       0
# 1    video_0_frame_0-00-56.02_flag_0_violation_0.jpg     0-00-56.02       0
# 2    video_0_frame_0-00-57.02_flag_0_violation_0.jpg     0-00-57.02       0
# 3    video_0_frame_0-00-58.02_flag_0_violation_0.jpg     0-00-58.02       0
# 4    video_0_frame_0-00-59.03_flag_0_violation_0.jpg     0-00-59.03       0
# ..                                               ...            ...     ...
# 551  video_1_frame_0-06-55.01_flag_0_violation_4.jpg     0-06-55.01       0
# 552  video_1_frame_0-06-56.02_flag_0_violation_4.jpg     0-06-56.02       0
# 553  video_1_frame_0-06-57.02_flag_0_violation_4.jpg     0-06-57.02       0
# 554  video_1_frame_0-06-58.02_flag_0_violation_4.jpg     0-06-58.02       0
# 555  video_1_frame_0-06-59.02_flag_0_violation_4.jpg     0-06-59.02       0
#
#     description
# 0          None
# 1          None
# 2          None
# 3          None
# 4          None
# ..          ...
# 551        None
# 552        None
# 553        None
# 554        None
# 555        None
#
# [556 rows x 6 columns]

# %%
image_result_info[image_result_info.target==1]
# Out:
#                                         video_name  video_num  \
# 10   0000000_00000020240221082923_0001_IMP (1).mp4          0
# 11   0000000_00000020240221082923_0001_IMP (1).mp4          0
# 12   0000000_00000020240221082923_0001_IMP (1).mp4          0
# 13   0000000_00000020240221082923_0001_IMP (1).mp4          0
# 14   0000000_00000020240221082923_0001_IMP (1).mp4          0
# ..                                             ...        ...
# 546  0000000_00000020240221082923_0001_IMP (1).mp4          0
# 547  0000000_00000020240221082923_0001_IMP (1).mp4          0
# 548  0000000_00000020240221082923_0001_IMP (1).mp4          0
# 549  0000000_00000020240221082923_0001_IMP (1).mp4          0
# 550  0000000_00000020240221082923_0001_IMP (1).mp4          0
#
#                                           image_name frame_duration  target  \
# 10   video_0_frame_0-06-00.03_flag_1_violation_1.jpg     0-06-00.03       1
# 11   video_0_frame_0-06-01.03_flag_1_violation_1.jpg     0-06-01.03       1
# 12   video_0_frame_0-06-02.03_flag_1_violation_1.jpg     0-06-02.03       1
# 13   video_0_frame_0-06-03.03_flag_1_violation_1.jpg     0-06-03.03       1
# 14   video_0_frame_0-06-04.03_flag_1_violation_1.jpg     0-06-04.03       1
# ..                                               ...            ...     ...
# 546  video_0_frame_0-14-56.03_flag_1_violation_1.jpg     0-14-56.03       1
# 547  video_0_frame_0-14-57.03_flag_1_violation_1.jpg     0-14-57.03       1
# 548  video_0_frame_0-14-58.03_flag_1_violation_1.jpg     0-14-58.03       1
# 549  video_0_frame_0-14-59.03_flag_1_violation_1.jpg     0-14-59.03       1
# 550  video_0_frame_0-15-00.03_flag_1_violation_1.jpg     0-15-00.03       1
#
#                                       description
# 10   Встал на подножку до полной остановки поезда
# 11   Встал на подножку до полной остановки поезда
# 12   Встал на подножку до полной остановки поезда
# 13   Встал на подножку до полной остановки поезда
# 14   Встал на подножку до полной остановки поезда
# ..                                            ...
# 546  Встал на подножку до полной остановки поезда
# 547  Встал на подножку до полной остановки поезда
# 548  Встал на подножку до полной остановки поезда
# 549  Встал на подножку до полной остановки поезда
# 550  Встал на подножку до полной остановки поезда
#
# [541 rows x 6 columns]
